# %% [markdown]
# <a href="https://colab.research.google.com/github/katie0carlson/Phys_Lab4_Repo/blob/main/Pendulum_Motion2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('Lab2Data.csv')
for i in range(1,19):
  time = df[f'Time (s) Run #{i}']
  theta_r = df[f'Angle, Ch 1+2 (rad) Run #{i}']
  '''
  dtheta_r = df[f'Angular Velocity, Ch 1+2 (rad/s) Run #{i}']
  alpha_r = df[f'Angular Acceleration, Ch 1+2 (rad/s²) Run #{i}']
  position_r = df[f'Position, Ch 1+2 (m) Run #{i}']
  velocity_r = df[f'Velocity, Ch 1+2 (m/s) Run #{i}']
  acceleration_r = df[f'Acceleration, Ch 1+2 (m/s²) Run #{i}']
  '''
  theta_l = df[f'Angle, Ch 3+4 (rad) Run #{i}']
  '''
  dtheta_l = df[f'Angular Velocity, Ch 3+4 (rad/s) Run #{i}']
  alpha_l = df[f'Angular Acceleration, Ch 3+4 (rad/s²) Run #{i}']
  position_l = df[f'Position, Ch 3+4 (m) Run #{i}']
  velocity_l = df[f'Velocity, Ch 3+4 (m/s) Run #{i}']
  acceleration_l = df[f'Acceleration, Ch 3+4 (m/s²) Run #{i}']
  '''
  plt.plot(time,theta_r,'r.',label=f'(R) Theta v. Time ({i})')
  plt.plot(time,theta_l,'c.',label=f'(L) Theta v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print()
  '''
  plt.plot(time,dtheta_r,'g.',label=f'(R) DTheta v. Time ({i})')
  plt.plot(time,dtheta_l,'y.',label=f'(L) DTheta v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print()
  plt.plot(time,alpha_r,'b.',label=f'(R) Alpha v. Time ({i})')
  plt.plot(time,alpha_l,'y.',label=f'(L) Alpha v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print('')
  plt.plot(time,position_r,'r.',label=f'(R) Position v. Time ({i})')
  plt.plot(time,position_l,'c.',label=f'(L) Position v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print()
  plt.plot(time,velocity_r,'g.',label=f'(R) Velocity v. Time ({i})')
  plt.plot(time,velocity_l,'y.',label=f'(L) Velocity v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print()
  plt.plot(time,acceleration_r,'b.',label=f'(R) Acceleration v. Time ({i})')
  plt.plot(time,acceleration_l,'y.',label=f'(L) Acceleration v. Time ({i})')
  plt.xlabel('Time (s)')
  plt.legend()
  plt.show();
  print()
  '''
  if i==18:
    theta_3 = df[f'Angle, Ch P1 (rad) Run #{i}']
    dtheta_3 = df[f'Angular Velocity, Ch P1 (rad/s) Run #{i}']
    alpha_3 = df[f'Angular Acceleration, Ch P1 (rad/s²) Run #{i}']
    plt.plot(time,theta_r,'r.',label=f'(R) Theta v. Time')
    plt.plot(time,theta_l,'c.',label=f'(L) Theta v. Time')
    plt.plot(time,theta_3,'g.',label=f'(M) Theta v. Time')
    plt.xlabel('Time (s)')
    plt.legend()
    plt.show();
    print()
    '''
    plt.plot(time,dtheta_r,'r.',label=f'(R) Theta v. Time')
    plt.plot(time,dtheta_l,'c.',label=f'(L) Theta v. Time')
    plt.plot(time,dtheta_3,'g.',label=f'(M) Theta v. Time')
    plt.xlabel('Time (s)')
    plt.legend()
    plt.show();
    print()
    plt.plot(time,alpha_r,'r.',label=f'(R) Theta v. Time')
    plt.plot(time,alpha_l,'c.',label=f'(L) Theta v. Time')
    plt.plot(time,theta_3,'g.',label=f'(M) Theta v. Time')
    plt.xlabel('Time (s)')
    plt.legend()
    plt.show();
    print()
    '''
# Out:
# <ipython-input-11-dd8013a214ad>:4: DtypeWarning: Columns (0,14,28,42,56,70,84,98,112,126,140,154,168,196,210,224,238) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Lab2Data.csv')
